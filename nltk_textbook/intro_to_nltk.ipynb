# %% [markdown]
# # Language Processing and Python
#
# ## 1.2   Getting Started with NLTK

# %%
# Import PyDictionary to define words
# Import nltk to learn Natural Language Processing
from PyDictionary import PyDictionary
import nltk
from nltk.corpus import stopwords
from nltk.book import *

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
from spacy.lang.en.stop_words import STOP_WORDS

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Display the texts (Corpous) available to us. These texts are built into nltk.
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Displays the first sentences of the texts available to us.
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %% [markdown]
# ## 1.3   Searching Text
#
# There are many ways to examine the context of a text apart from simply reading it!
#
# For example, the `text` type objects have a method named `concordance()`. A __concordance__ view shows us every occurrence of a given word, together with some context. Here we look up the word monstrous in Moby Dick by entering text1 followed by a period, then the term concordance, and then placing "monstrous" in parentheses:

# %%
PyDictionary.meaning("Monstrous")
# Out:
# {'Adjective': ['abnormally large',
#   'shockingly brutal or cruel',
#   'distorted and unnatural in shape or size; abnormal and hideous']}

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance('provision')
# Out:
# Displaying 4 of 4 matches:
# ear to him , and who most needed a provision by any charge on the estate , or b
#  was persuaded that a much smaller provision than 7000L would support her in af
# ght to be of the party , by way of provision for discourse . In the present cas
# s of a nurse , for the sake of the provision and security of a wife . In his ma

# %%
text3.concordance('God')
# Out:
# Displaying 25 of 231 matches:
# In the beginning God created the heaven and the earth . An
#  face of the deep . And the Spirit of God moved upon the face of the waters . A
# ved upon the face of the waters . And God said , Let there be light : and there
#  be light : and there was light . And God saw the light , that it was good : an
# aw the light , that it was good : and God divided the light from the darkness .
# ded the light from the darkness . And God called the light Day , and the darkne
#  the morning were the first day . And God said , Let there be a firmament in th
# vide the waters from the waters . And God made the firmament , and divided the
# above the firmame and it was so . And God called the firmament Heaven . And the
# the morning were the second day . And God said , Let the waters under the heave
# the dry land appe and it was so . And God called the dry land Earth ; and the g
# gether of the waters called he Se and God saw that it was good . And God said ,
# ...

# %% [markdown]
# The concordance attribute allows us to see a word in __context__. We can use the `.simiilar()` method to access text that appears in a similar range of context.

# %%
text1.similar('live')
# Out:
# be it right him them whale say go open me white speak stay you take
# thee great side swim head

# %%
text3.similar('life')
# Out:
# house name brother cattle blood son fowls money thigh god heaven it
# good land fruit fowl beast lord sight knowledge

# %% [markdown]
# The method `.common_contexts([])` allows us to analyze a list of words that share a similar context. Put another way, it allows us to see words that occur together.

# %%
text3.common_contexts(['God', 'Blessed'])
# Out:
# the_of said_be

# %% [markdown]
# In addition to displaying words in context, both single and collection, we can analyze the dispersion of words! __Dispersion__ in the context of Natural Language Processing means the "distance" from the beginning a word appears. The distance, or position, or location, can be visualized using a __dispersion plot__!

# %%
lineage = ['God', 'Adam', 'Seth', 'Enosh', 'Kenan', 'Mahalalel', 'Jared', 'Enoch',
           'Methuselah', 'Lamech', 'Noah', 'Shem', 'Arphaxad', 'Cainan', 'Shelah',
           'Eber', 'Peleg', 'Abraham', 'Isaac', 'Jacob', 'Joseph']

# This is so cool! Ingenious and intuitive!
sns.set_context('talk')
plt.figure(figsize=(8, 6))
text3.dispersion_plot(lineage);
plt.tight_layout()

# %% [markdown]
# Text can also be generated using the `.generate()` method! Let's see it in action.
#
# ```python
# Signature: text4.generate(length=100, text_seed=None, random_seed=42)
# Docstring:
# Print random text, generated using a trigram language model.
# See also `help(nltk.lm)`.
#
# :param length: The length of text to generate (default=100)
# :type length: int
#
# :param text_seed: Generation can be conditioned on preceding context.
# :type text_seed: list(str)
#
# :param random_seed: A random seed or an instance of `random.Random`. If provided,
# makes the random sampling part of generation reproducible. (default=42)
# :type random_seed: int
# ```

# %%
text4.generate(random_seed=369)
# Out:
# Building ngram index...
# sacred trust twice confided to me that the sentiments of our sons made
# soldiers to deluge with blood . and intelligent comprehension of
# rights is now three days more than this , principal and interest , of
# observing its international obligations of the world environment , the
# fears of many new ones and unite the free exercise is deemed necessary
# to insure the continuance of our constituents can not but overwhelm
# with despondence one who would die for the improvement and growth of
# manufactures in the words of Micah and renewed through two centuries
# ago our Nation and State ,
# ...

# %%
text3.generate(random_seed=369)
# Out:
# Building ngram index...
# sent us to mock And it came to pass the third river is Hiddekel : that
# is therein , and said , We saw certainly that the LORD appeared unto
# him , and begat Reu two hundred and nineteen years , and multiply ,
# and said , Lay not thine hand ; because that I may eat , and bracelets
# upon her hands . Jacob blessed Pharaoh . ; we dreamed a dream by night
# , and he was come near her : yea , I have served thee , than that I
# lifted up his eyes and looked toward
# 'sent us to mock And it came to pass the third river is Hiddekel : that\nis therein , and said , We saw certainly that the LORD appeared unto\nhim , and begat Reu two hundred and nineteen years , and multiply ,\nand said , Lay not thine hand ; because that I may eat , and bracelets\nupon her hands . Jacob blessed Pharaoh . ; we dreamed a dream by night\n, and he was come near her : yea , I have served thee , than that I\nlifted up his eyes and looked toward'

# %% [markdown]
# ## 1.4 Counting Vocabulary
#
# Texts vary in the vocabulary they use. This module will teach us techniques to count and analyze the vocabulary for our texts.

# %%
# We can count the number of words in a text using the len() function
len(text1)
# Out:
# 260819

# %% [markdown]
# When text is wrapped and in the `set()` function, it returns a set of unique words. Wrapping the `set()` function with a `sorted()` function returns a list of sorted words in lexilogical order. Special characters are sorted first, followed by words starting with 'A'. When sorting words, capital words and capital letters always precede lowercase words.
#
# 1. All Uppercase
# 2. Capitalized
# 3. All lowercase

# %%
sorted(set(text1))
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %% [markdown]
# To calculate a measure of the lexical richness of the text divide the distinct words by the total number of words in the text.

# %%
print(f"There are {len(set(text1))} unique words in {text1}")
# Out:
# There are 19317 unique words in <Text: Moby Dick by Herman Melville 1851>

# %%
print(f"{len(set(text1))/len(text1):.0%} of the words in {text1} are distinct")
# Out:
# 7% of the words in <Text: Moby Dick by Herman Melville 1851> are distinct

# %% [markdown]
# #### Question
# How many times does the word `lol` appear in `text5`? How much is this as a percentage of the total number of words in this text?
#
# #### Answer
# The word "lol" appears 704 times in the Chat Corpus. This makes up about 1.6% of all words used in the Chat Corpus.

# %%
text5
# Out:
# <Text: Chat Corpus>

# %%
text5.count('lol')
# Out:
# 704

# %%
round(text5.count('lol') / len(text5), 3) * 100
# Out:
# 1.6

# %% [markdown]
# Create functions to calculate the lexical diversity of a text.

# %%
def lexical_diversity(text=None):
    '''
    This function accepts a text object from nltk and returns the lexical diversity of the text.
    Lexical diversity is the percentage of distinct words divided by the total number of words
    in a text.
    
    Parameters
    ----------
    text : nltk text object, default None
    nltk's built-in Corpi available via
        
        import nltk
        nltk.download()
        
    Returns
    -------
    lexi_diversity : float
    The percentage of distinct words in the text defined as the number of distinct words
    divided by the total number of words in a text.
    '''
    # Create variables to store the count of distinct words and total words
    distinct_word_count = len(set(text))
    word_total = len(text)
    
    # Calculate the lexical diversity of the text
    lexi_diversity = distinct_word_count / word_total
    
    #Display the lexical diversity of the text as a percentage.
    print(f"The lexical diversity of {text} is {lexi_diversity:0.2%}")
    
    # Return the lexical diversity of the text as a decimal
    return lexi_diversity


def word_percentage(word='a', text=None):
    '''
    This function accepts a word and an nltk text object. It returns the percentage of the text that is made
    up of the word passed to the `word` parameter.
    
    Parameters
    ----------
    word : str, default 'a'
    A vocabulary word defined in the English language.
    
    text : nltk text object, default None
    nltk's built-in Corpi available via
        
        import nltk
        nltk.download()
        
    Returns
    -------
    percentage : float
    The number of times a word appears in a text divided by the total number of words in a text.
    '''
    # Create variables to store the count of word and the count of words in the text/corpus
    word_count = text.count(word)
    total = len(text)
    
    # Calculate the percentage of the text made up from the `word` parameter
    percentage = word_count / total
    
    # Display the number of times a word appears in a text as a percentage of the total words in the text.
    print(f"The word \"{word}\" consitutes {percentage:0.2%} of the text: {text}")
    
    # Return the value as a decimal.
    return percentage

# %%
lexical_diversity(text1)
# Out:
# The lexical diversity of <Text: Moby Dick by Herman Melville 1851> is 7.41%
# 0.07406285585022564

# %%
word_percentage(word='Whale', text=text1)
# Out:
# The word "Whale" consitutes 0.11% of the text: <Text: Moby Dick by Herman Melville 1851>
# 0.0010812095744558486

# %% [markdown]
# # 2   A Closer Look at Python: Texts as Lists of Words
# "What is a text? At one level, it is a sequence of symbols on a page such as this one. At another level, it is a sequence of chapters, made up of a sequence of sections, where each section is a sequence of paragraphs, and so on. However, for our purposes, we will think of a text as nothing more than a sequence of words and punctuation." [source](https://www.nltk.org/book/ch01.html)
# ## 2.1   Lists

# %%
# sent1 is a variable that stores the first sentence of Moby Dick.
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
# Calculate the lexical diversity of the first sentence of Moby Dick.
lexical_diversity(sent1)
# Out:
# The lexical diversity of ['Call', 'me', 'Ishmael', '.'] is 100.00%
# 1.0

# %%
# Calculate the percentage of the sentence made up of the word "Call"
word_percentage('Call', sent1)
# Out:
# The word "Call" consitutes 25.00% of the text: ['Call', 'me', 'Ishmael', '.']
# 0.25

# %%
# sent2 is the first sentence of Sense and Sensibility by Jane Austen 1811
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
# sent3 is the first sentence of the Book of Genesis
sent3
# Out:
# ['In',
#  'the',
#  'beginning',
#  'God',
#  'created',
#  'the',
#  'heaven',
#  'and',
#  'the',
#  'earth',
#  '.']

# %%
# Lists of strings can be combined using the `+` operator or the extend() method.
# BECAREFUL! using the .extend method will join the second list to the first list, INPLACE.
sent1 + sent2
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %% [markdown]
# ```python
# sent1.extend(sent2)
# ```
#
# If we want to add a single word to a list, we can use the `.append()` method

# %%
sent1.append('Verily')
print(sent1)
# Out:
# ['Call', 'me', 'Ishmael', '.', 'Verily']

# %%
sent1.pop()
# Out:
# 'Verily'

# %% [markdown]
# ## 2.2   Indexing Lists
#
# Since were manipulating list objects, we can use index notation to access individual words in a text.

# %%
# Indexing notation with a single number returns the element at that index
# In this case, the word at index 369 is the word 'these'
text1[369]
# Out:
# 'these'

# %%
# Similarly, accessing the list of words called 'text2' using index notation
# Allows us to retrieve the element at index 42, the word where.
text2[42]
# Out:
# 'where'

# %%
# Using the .index method, will allow us to return an index value for a given word/element.
text1.index('Ishmael')
# Out:
# 4714

# %%
# Elements of a list can also be accessed using slice notation, also called 'Spans' in spaCy.
text1[:20]
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.',
#  '(',
#  'Supplied',
#  'by',
#  'a',
#  'Late',
#  'Consumptive',
#  'Usher',
#  'to',
#  'a',
#  'Grammar']

# %% [markdown]
# Bookmark: https://www.nltk.org/book/ch01.html

# %%
# Using index or slice notation, you can replace elements in a list.
sentence = 'This is a an example to show you the power of index and slice modification'
list_of_words = sentence.split()

# %%
list_of_words[0:4] = "THIS IS A SENTENCE".split()

# %%
list_of_words
# Out:
# ['THIS',
#  'IS',
#  'A',
#  'SENTENCE',
#  'example',
#  'to',
#  'show',
#  'you',
#  'the',
#  'power',
#  'of',
#  'index',
#  'and',
#  'slice',
#  'modification']

# %%
list_of_words[-3:] = "AND KARATE-CHOP SKILLS".split()

# %%
list_of_words
# Out:
# ['THIS',
#  'IS',
#  'A',
#  'SENTENCE',
#  'example',
#  'to',
#  'show',
#  'you',
#  'the',
#  'power',
#  'of',
#  'index',
#  'AND',
#  'KARATE-CHOP',
#  'SKILLS']

# %% [markdown]
# ## 3   Computing with Language: Simple Statistics
#
# Using a frequency distribution allows us to see the number of times a word occurs in a text. `FreqDist()` is a function that allows us to create a frequency distribution of words from a list of strings or a Text Object.

# %%
# FreqDist creates a dictionary of word: # of occurances.
FreqDist(text1)
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
# The FreqDist function creates a set of unique words with the total number of words in the text.
print(FreqDist(text1))
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
# The number of samples matches the number of unique words in the text.
len(set(text1))
# Out:
# 19317

# %% [markdown]
# ### Frequency Distribution of Words in a Text

# %%
# The 20 most frequently occuring words in Moby Dick.
sns.set_context('talk')
FreqDist(text1).plot(20, cumulative=True);

# %% [markdown]
# ### Frequency Distribution of Unique Words in a Text

# %%
# Create a variable to store Moby Dick with stop words removed.
filtered_text1 = [word.lower() for word in text1 if word.isalpha() and word not in STOP_WORDS]

# %%
# Plot the distribution of non-stopwords in Moby Dick.
sns.set_context('talk')
FreqDist(filtered_text1).plot(20, cumulative=True);

# %%
def plot_word_distribution(text=text1, unique=False, metadata=False):
    '''
    This function accepts a list of strings or Text object from nltk
    and returns a frequency distribution plot of the 10 most frequently occuring words.
    
    Parameters
    ----------
    text : list, default nltk Text Object
        A list of strings or a Text object provided by nltk.book *
    
    unique : boolean, default False
        If unique is True, the function will return a frequency distribution plot
        of distinct, alpha, non-stopwords words in a text.
        If False, returns a frequency distribution plot of words that occur in the text.
        
    metadata : boolean, default False
        Returns the number of unique words and the total number of words in a text.
        If True, metadata will print for the user to see. If False, returns nothing.
    
    Returns
    -------
    None
    '''
    
    # Lowercase all of the words in the text
    text_lowered = [word.lower() for word in text]
    
    # Display the metadata if the User requests it
    if metadata is True:
        print(FreqDist(text))
    
    # If the User wants to plot the distinct words in a text, remove stopwords and non alpha words.
    if unique is True:
        filtered_text = [word for word in text_lowered if word.isalpha() and word not in STOP_WORDS]
        
        # Plot the distribution of the 10 most frequently occuring distinct words.
        FreqDist(filtered_text).plot(10, cumulative=True)
    else:
        # Plot the distribution of the 10 most frequently occuring words.
        FreqDist(text_lowered).plot(10, cumulative=True)

# %%
sns.set_context('talk')
plot_word_distribution(text3)

# %%
sns.set_context('talk')
plot_word_distribution(text3, unique=True, metadata=True)
# Out:
# <FreqDist with 2789 samples and 44764 outcomes>

# %%
for i in range(1, 10):
    exec(f'distinct_text = text{i}')
    print(distinct_text)
    plot_word_distribution(distinct_text, unique=True, metadata=True)
# Out:
# <Text: Moby Dick by Herman Melville 1851>
# <FreqDist with 19317 samples and 260819 outcomes>
# <Text: Sense and Sensibility by Jane Austen 1811>
# <FreqDist with 6833 samples and 141576 outcomes>
# <Text: The Book of Genesis>
# <FreqDist with 2789 samples and 44764 outcomes>
# <Text: Inaugural Address Corpus>
# <FreqDist with 9913 samples and 149797 outcomes>
# <Text: Chat Corpus>
# <FreqDist with 6066 samples and 45010 outcomes>
# <Text: Monty Python and the Holy Grail>
# <FreqDist with 2166 samples and 16967 outcomes>
# <Text: Wall Street Journal>
# <FreqDist with 12408 samples and 100676 outcomes>
# <Text: Personals Corpus>
# <FreqDist with 1108 samples and 4867 outcomes>
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>
# <FreqDist with 6807 samples and 69213 outcomes>
